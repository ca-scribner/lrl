# %% [markdown]
# # Example Case using Racetrack
#
# Below is an example of how to initialize the Racetrack environment and solve/compare with multiple solvers.

# %% [markdown]
# ## Boilerplate

# %% [markdown]
# If you're playing with things under the hood as you run these, autoreload is always useful...

# %%
# %load_ext autoreload

# %autoreload 2

# %% [markdown]
# If necessary, add directory containing lrl to path (workaround for if lrl is not installed as a package)

# %%
import sys

# Path to directory containing lrl
sys.path.append('../')

# %%
from lrl import environments, solvers
from lrl.utils import plotting

import matplotlib.pyplot as plt

# %% [markdown]
# Logging is used throughout lrl for basic info and debugging.

# %%
import logging
logging.basicConfig(format='%(asctime)s - %(name)s - %(funcName)s - %(levelname)s - %(message)s',
                    level=logging.INFO, datefmt='%H:%M:%S')
logger = logging.getLogger(__name__)

# %% [markdown]
# ## Initialize an Environment

# %% [markdown]
# Initialize the 20x10 racetrack that includes some oily (stochastic) surfaces.
#
# **Note**: Make sure that your velocity limits suit your track.  A track must have a grass padding around the entire course that prevents a car from trying to exit the track entirely, so if max(abs(vel))==3, you need 3 grass tiles around the outside perimeter of your map.  For track, we have a 2-tile perimeter so velocity must be less than +-2.

# %%
# This will raise an error due to x_vel max limit
try:
    rt = environments.get_racetrack(track='20x10_U',
                                     x_vel_limits=(-2, 20),  # Note high x_vel upper limit
                                     y_vel_limits=(-2, 2),
                                     x_accel_limits=(-2, 2),
                                     y_accel_limits=(-2, 2),
                                     max_total_accel=2,
                                     )
except IndexError as e:
    print("Caught the following error while building a track that shouldn't work:")
    print(e)
    print("")

# This will work
try:
    rt = environments.get_racetrack(track='20x10_U',
                                 x_vel_limits=(-2, 2),
                                 y_vel_limits=(-2, 2),
                                 x_accel_limits=(-2, 2),
                                 y_accel_limits=(-2, 2),
                                 max_total_accel=2,
                                 )
    print("But second track built perfectly!")
except:
    print("Something went wrong, we shouldn't be here")
# Out:
# Caught the following error while building a track that shouldn't work:
# Caught IndexError while building Racetrack.  Likely cause is a max velocity that is creater than the wall padding around the track (leading to a car that can exit the track entirely)
#
# But second track built perfectly!

# %% [markdown]
# Take a look at the track using plot_env

# %%
plotting.plot_env(env=rt)

# %% [markdown]
# There are also additional maps available - see the racetrack code base for more

# %%
print(f'Available tracks: {list(environments.racetrack.TRACKS.keys())}')
# Out:
# Available tracks: ['3x4_basic', '5x4_basic', '10x10', '10x10_basic', '10x10_all_oil', '15x15_basic', '20x20_basic', '20x20_all_oil', '30x30_basic', '20x10_U_all_oil', '20x10_U', '10x10_oil', '20x15_risky']

# %% [markdown]
# Tracks are simply lists of strings using a specific set of characters.  See the racetrack code for more detail on how to make your own

# %%
for line in environments.racetrack.TRACKS['20x10_U']:
    print(line)
# Out:
# GGGGGGGGGGGGGGGGGGGG
# GGGGGGGGGGGGGGGGGGGG
# GGG     OOOO      GG
# GGG     GGGG      GG
# GGOOOOGGGGGGGGOOOOGG
# GGOOOGGGGGGGGGGOOOGG
# GG    GGGGGGGG    GG
# GG      SGGGGG    GG
# GGGGGGGGGGGGGGFFFFGG
# GGGGGGGGGGGGGGFFFFGG

# %% [markdown]
# We can draw them using character art!  For example, here is a custom track with more oil and a different shape than above...

# %%
custom_track = \
"""GGGGGGGGGGGGGGGGGGGG
GGGGGGGGGGGGGGGGGGGG
GGGOOOOOOOOOOOOOOOGG
GGG     GGGG      GG
GG    GGGGGGGG    GG
GGOOOOOOSGGGGGOOOOGG
GGGGGGGGGGGGGGFFFFGG
GGGGGGGGGGGGGGFFFFGG"""
custom_track = custom_track.split('\n')

# %%
rt_custom = environments.get_racetrack(track=custom_track,
                                 x_vel_limits=(-2, 2),
                                 y_vel_limits=(-2, 2),
                                 x_accel_limits=(-2, 2),
                                 y_accel_limits=(-2, 2),
                                 max_total_accel=2,
                                 )

# %%
plotting.plot_env(env=rt_custom)

# %% [markdown]
# ## Solve with Value Iteration and Interrogate Solution

# %%
rt_vi = solvers.ValueIteration(env=rt)
rt_vi.iterate_to_convergence()
# Out:
# 15:50:35 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Solver iterating to convergence (Max delta in value function < 0.001 or iters>500)
# 15:50:38 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Solver converged to solution in 18 iterations

# %% [markdown]
# And we can then score our solution by running it multiple times through the environment

# %%
scoring_data = rt_vi.score_policy(iters=500)

# %% [markdown]
# score_policy returns a WalkStatistics object that contains details from each episode taken during the scoring.  Easiest way to interact with it is grabbing data as a dataframe

# %%
print(f'type(scoring_data) = {type(scoring_data)}')
scoring_data_df = scoring_data.to_dataframe(include_walks=True)
scoring_data_df.head(3)
# Out:
# type(scoring_data) = <class 'lrl.data_stores.data_stores.WalkStatistics'>
#    walk_index  reward  steps  terminal  reward_mean  reward_median  \
# 0           0    91.0     11      True         91.0           91.0
# 1           1    91.0     11      True         91.0           91.0
# 2           2    91.0     11      True         91.0           91.0
#
#    reward_std  reward_min  reward_max  steps_mean  steps_median  steps_std  \
# 0         0.0        91.0        91.0        11.0          11.0        0.0
# 1         0.0        91.0        91.0        11.0          11.0        0.0
# 2         0.0        91.0        91.0        11.0          11.0        0.0
#
#    steps_min  steps_max  terminal_fraction  \
# 0         11         11                1.0
# 1         11         11                1.0
# 2         11         11                1.0
#
#                                                walks
# 0  [(8, 2, 0, 0), (6, 2, -2, 0), (5, 3, -1, 1), (...
# 1  [(8, 2, 0, 0), (6, 2, -2, 0), (5, 3, -1, 1), (...
# 2  [(8, 2, 0, 0), (6, 2, -2, 0), (5, 3, -1, 1), (...

# %%
scoring_data_df.tail(3)
# Out:
#      walk_index  reward  steps  terminal  reward_mean  reward_median  \
# 497         497    89.0     13      True    90.473896           91.0
# 498         498    91.0     11      True    90.474950           91.0
# 499         499    91.0     11      True    90.476000           91.0
#
#      reward_std  reward_min  reward_max  steps_mean  steps_median  steps_std  \
# 497    0.880581        89.0        91.0   11.526104          11.0   0.880581
# 498    0.880013        89.0        91.0   11.525050          11.0   0.880013
# 499    0.879445        89.0        91.0   11.524000          11.0   0.879445
#
#      steps_min  steps_max  terminal_fraction  \
# 497         11         13                1.0
# 498         11         13                1.0
# 499         11         13                1.0
#
#                                                  walks
# 497  [(8, 2, 0, 0), (6, 2, -2, 0), (5, 3, -1, 1), (...
# 498  [(8, 2, 0, 0), (6, 2, -2, 0), (5, 3, -1, 1), (...
# 499  [(8, 2, 0, 0), (6, 2, -2, 0), (5, 3, -1, 1), (...

# %% [markdown]
# Reward, Steps, and Terminal columns give data on that specific walk, whereas reward_mean, \_median, etc. columns give aggregate scores up until that walk.  For example:

# %%
print(f'The reward obtained in the 499th walk was {scoring_data_df.loc[499, "reward"]}')
print(f'The mean reward obtained in the 0-499th walks (inclusive) was {scoring_data_df.loc[499, "reward_mean"]}')
# Out:
# The reward obtained in the 499th walk was 91.0
# The mean reward obtained in the 0-499th walks (inclusive) was 90.476

# %% [markdown]
# And we can access the actual episode path for each episode

# %%
print(f'Episode 0 (directly)          : {scoring_data.walks[0]}')
print(f'Episode 0 (from the dataframe): {scoring_data_df.loc[0, "walks"]}')
# Out:
# Episode 0 (directly)          : [(8, 2, 0, 0), (6, 2, -2, 0), (5, 3, -1, 1), (5, 5, 0, 2), (7, 7, 2, 2), (9, 7, 2, 0), (11, 7, 2, 0), (13, 6, 2, -1), (15, 4, 2, -2), (15, 2, 0, -2), (14, 0, -1, -2)]
# Episode 0 (from the dataframe): [(8, 2, 0, 0), (6, 2, -2, 0), (5, 3, -1, 1), (5, 5, 0, 2), (7, 7, 2, 2), (9, 7, 2, 0), (11, 7, 2, 0), (13, 6, 2, -1), (15, 4, 2, -2), (15, 2, 0, -2), (14, 0, -1, -2)]

# %% [markdown]
# ## Plotting Results

# %% [markdown]
# And plot 100 randomly chosen episodes on the map, returned as a matplotlib axes

# %%
ax_episodes = plotting.plot_episodes(episodes=scoring_data.walks, env=rt, max_episodes=100, )

# %% [markdown]
# score_policy also lets us use hypothetical scenario, such as what if we started in a different starting location.  Let's try that by starting in the top left ((x,y) location (3, 7) (x=0 at left, y=0 at bot)) with a velocity of (1, -1), and plot it to our existing axes in red.

# %%
scoring_data_alternate = rt_vi.score_policy(iters=500, initial_state=(3, 7, -2, -2))
ax_episodes_with_alternate = plotting.plot_episodes(episodes=scoring_data_alternate.walks, add_env_to_plot=False, 
                                                    color='r', ax=ax_episodes
#                                                     savefig='my_figure_file',  # If you wanted the figure to save directly 
                                                                                 # to file, use savefig (used throughout 
                                                                                 # lrl's plotting scripts)
                                                    )

# Must get_figure because we're reusing the figure from above and jupyter wont automatically reshow it
ax_episodes_with_alternate.get_figure()
# Out:
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it
# 15:50:44 - lrl.utils.plotting - plot_episode - WARNING - env arg not strictly required, but often needs to be specified so is advisable to include it

# %% [markdown]
# Where we can see the optimal policy takes a first action of (+2, 0) resulting in a first velocity of (0, -2) to avoid hitting the grass on step 1, then it redirects back up and around the track (although it sometimes slips on (3, 5) and drives down to (3, 3) before recovering)

# %% [markdown]
# We can also look at the Value function and best policy for all states
#
# **NOTE**: Because state is (x, y, v_x, v_y), it is hard to capture all results on our (x, y) maps.  plot_solver_results in this case plots a map for each (v_x, v_y) combination, with the axis title denoting which is the case.

# %%
# Sorry, this will plot 24 plots normally.  
# To keep concise, we turn matplotlib inline plotting off then back on and selectively plot a few examples
# %matplotlib agg
ax_results = plotting.plot_solver_results(env=rt, solver=rt_vi)
# %matplotlib inline
# Out:
# C:\Users\Scribs\Anaconda3\envs\lrl\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# Plots are indexed by the additional state variables (v_x, v_y), so we can see the policy for v_x=0, v_y=0 like:

# %%
ax_results[(0, 0)].get_figure()

# %% [markdown]
# Where we can see the estimated value of the starting (light green) location is 30.59 (including discounting and costs for steps).

# %% [markdown]
# We can also look at the policy for (-2, -2) (the velocity for our alternate start used above in red):

# %%
ax_results[(-2, -2)].get_figure()

# %% [markdown]
# Where we in the top left tile (3, 7) the optimal policy is (2, 0), just as we saw in our red path plot above.
#
# We can also see that tile (2, 2) (bottom left) has a -100 value because it is impossible to not crash with a (-2, -2) initialial velocity from tile (2, 2) given that our acceleration limit is 2.

# %% [markdown]
# ## Solving with Policy Iteration and Comparing to Value Iteration

# %% [markdown]
# We can also use other solvers

# %%
rt_pi = solvers.PolicyIteration(env=rt)
rt_pi.iterate_to_convergence()
# Out:
# 15:50:56 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Solver iterating to convergence (1 iteration without change in policy or iters>500)
# 15:51:00 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Solver converged to solution in 6 iterations

# %% [markdown]
# We can look at how PI and VI converged relative to each other, comparing the maximum change in value function for each iteration

# %%
# (these are simple convenience functions for plotting, basically just recipes.  See the plotting API)
# We can pass the solver..
ax = plotting.plot_solver_convergence(rt_vi, label='vi')

# Or going a little deeper into the API, with style being passed to matplotlib's plot function...
ax = plotting.plot_solver_convergence_from_df(rt_pi.iteration_data.to_dataframe(), y='delta_max', x='iteration', ax=ax, label='pi', ls='', marker='o')

ax.legend()

# %% [markdown]
# And looking at policy changes per iteration

# %%
# (these are simple convenience functions for plotting, basically just recipes.  See the plotting API)
# We can pass the solver..
ax = plotting.plot_solver_convergence(rt_vi, y='policy_changes', label='vi')

# Or going a little deeper into the API...
ax = plotting.plot_solver_convergence_from_df(rt_pi.iteration_data.to_dataframe(), y='policy_changes', x='iteration', ax=ax, label='pi', ls='', marker='o')

ax.legend()

# %% [markdown]
# So we can see PI accomplishes more per iteration.  But, is it faster?  Let's look at time per iteration

# %%
# (these are simple convenience functions for plotting, basically just recipes.  See the plotting API)
# We can pass the solver..
ax = plotting.plot_solver_convergence(rt_vi, y='time', label='vi')

# Or going a little deeper into the API...
ax = plotting.plot_solver_convergence_from_df(rt_pi.iteration_data.to_dataframe(), y='time', x='iteration', ax=ax, label='pi', ls='', marker='o')

ax.legend()

print(f'Total solution time for Value Iteration (excludes any scoring time):  {rt_vi.iteration_data.to_dataframe().loc[:, "time"].sum():.2f}s')
print(f'Total solution time for Policy Iteration (excludes any scoring time): {rt_pi.iteration_data.to_dataframe().loc[:, "time"].sum():.2f}s')
# Out:
# Total solution time for Value Iteration (excludes any scoring time):  2.49s
# Total solution time for Policy Iteration (excludes any scoring time): 3.39s

# %% [markdown]
# ## Solve with Q-Learning

# %% [markdown]
# We can also use QLearning, although it needs a few parameters

# %%
# Let's be explicit with our QLearning settings for alpha and epsilon
alpha = 0.1  # Constant alpha during learning

# Decay function for epsilon (see QLearning() and decay_functions() in documentation for syntax)
# Decay epsilon linearly from 0.2 at timestep (iteration) 0 to 0.05 at timestep 1500, 
# keeping constant at 0.05 for ts>1500
epsilon = {
    'type': 'linear',
    'initial_value': 0.2, 
    'initial_timestep': 0,
    'final_value': 0.05, 
    'final_timestep': 1500
}

# Above PI/VI used the default gamma, but we will specify one here
gamma = 0.9

# Convergence is kinda tough to interpret automatically for Q-Learning.  One good way to monitor convergence is to
# evaluate how good the greedy policy at a given point in the solution is and decide if it is still improving.
# We can enable this with score_while_training (available for Value and Policy Iteration as well)
# NOTE: During scoring runs, the solver is acting greedily and NOT learning from the environment.  These are separate
#       runs solely used to estimate solution progress
# NOTE: Scoring every 50 iterations is probably a bit much, but used to show a nice plot below.  The default 500/500 
#       is probably a better general guidance
score_while_training = {
    'n_trains_per_eval': 50,  # Number of training episodes we run per attempt to score the greedy policy 
                               # (eg: Here we do a scoring run after every 500 training episodes, where training episodes
                               # are the usual epsilon-greedy exploration episodes)
    'n_evals': 250,  # Number of times we run through the env with the greedy policy whenever we score
}
# score_while_training = True  # This calls the default settings, which are also 500/500 like above

rt_ql = solvers.QLearning(env=rt, alpha=alpha, epsilon=epsilon, gamma=gamma,
                          max_iters=5000, score_while_training=score_while_training)

# %% [markdown]
# (note how long Q-Learning takes for this environment versus the planning algorithms)

# %%
rt_ql.iterate_to_convergence()
# Out:
# 15:51:02 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Solver iterating to convergence (20 episodes with max delta in Q function < 0.1 or iters>5000)
# 15:51:02 - lrl.solvers.learners - iterate - INFO - Performing iteration (episode) 0 of Q-Learning
# 15:51:02 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 50
# 15:51:03 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -102.0, r_max = -102.0
# 15:51:03 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 100
# 15:51:04 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -103.0, r_max = -103.0
# 15:51:04 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 150
# 15:51:04 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -103.0, r_max = -103.0
# 15:51:05 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 200
# 15:51:05 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -102.0, r_max = -102.0
# 15:51:06 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 250
# 15:51:06 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -102.0, r_max = -102.0
# 15:51:07 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 300
# 15:51:07 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -100.0, r_max = -100.0
# 15:51:08 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 350
# 15:51:08 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -103.0, r_max = -103.0
# 15:51:08 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 400
# 15:51:09 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -100.0, r_max = -100.0
# 15:51:10 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 450
# 15:51:10 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -104.0, r_max = -104.0
# 15:51:10 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 500
# 15:51:11 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -103.0, r_max = -103.0
# 15:51:11 - lrl.solvers.learners - iterate - INFO - Performing iteration (episode) 500 of Q-Learning
# 15:51:11 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 550
# 15:51:12 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -105.412, r_max = -105.0
# 15:51:13 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 600
# 15:51:13 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -103.0, r_max = -103.0
# 15:51:14 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 650
# 15:51:16 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -105.0, r_max = -105.0
# 15:51:16 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 700
# 15:51:17 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -103.0, r_max = -103.0
# 15:51:18 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 750
# 15:51:18 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -104.0, r_max = -104.0
# 15:51:19 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 800
# 15:51:19 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -100.0, r_max = -100.0
# 15:51:20 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 850
# 15:51:21 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -105.0, r_max = -105.0
# 15:51:21 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 900
# 15:51:21 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -104.648, r_max = -104.0
# 15:51:22 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 950
# 15:51:22 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -106.0, r_max = -106.0
# 15:51:23 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1000
# 15:51:24 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -104.0, r_max = -104.0
# 15:51:24 - lrl.solvers.learners - iterate - INFO - Performing iteration (episode) 1000 of Q-Learning
# 15:51:24 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1050
# 15:51:25 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -104.0, r_max = -104.0
# 15:51:25 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1100
# 15:51:26 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -106.292, r_max = -106.0
# 15:51:26 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1150
# 15:51:27 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -100.0, r_max = -100.0
# 15:51:27 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1200
# 15:51:28 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -106.0, r_max = -106.0
# 15:51:28 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1250
# 15:51:29 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -105.536, r_max = -105.0
# 15:51:29 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1300
# 15:51:30 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -109.196, r_max = -109.0
# 15:51:30 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1350
# 15:51:31 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -105.0, r_max = -105.0
# 15:51:31 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1400
# 15:51:32 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -105.636, r_max = -104.0
# 15:51:32 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1450
# 15:51:33 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -103.56, r_max = -100.0
# 15:51:33 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1500
# 15:51:34 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -106.72, r_max = -106.0
# 15:51:34 - lrl.solvers.learners - iterate - INFO - Performing iteration (episode) 1500 of Q-Learning
# 15:51:34 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1550
# 15:51:36 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -100.0, r_max = -100.0
# 15:51:37 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1600
# 15:51:38 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -106.0, r_max = -106.0
# 15:51:38 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1650
# 15:51:39 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -104.0, r_max = -104.0
# 15:51:40 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1700
# 15:51:40 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -109.0, r_max = -109.0
# 15:51:41 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1750
# 15:51:42 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -104.74, r_max = -100.0
# 15:51:42 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1800
# 15:51:43 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -107.0, r_max = -107.0
# 15:51:43 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1850
# 15:51:45 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -109.308, r_max = -108.0
# 15:51:45 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1900
# 15:51:46 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -105.616, r_max = -105.0
# 15:51:46 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 1950
# 15:51:48 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -106.544, r_max = -106.0
# 15:51:48 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 2000
# 15:51:49 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -110.852, r_max = -108.0
# 15:51:49 - lrl.solvers.learners - iterate - INFO - Performing iteration (episode) 2000 of Q-Learning
# 15:51:49 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 2050
# 15:51:50 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = -107.02, r_max = -106.0
# 15:51:50 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 2100
# 15:51:52 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean =
- lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 4450
# 15:53:29 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = 89.784, r_max = 90.0
# 15:53:30 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 4500
# 15:53:31 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = 89.764, r_max = 90.0
# 15:53:31 - lrl.solvers.learners - iterate - INFO - Performing iteration (episode) 4500 of Q-Learning
# 15:53:32 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 4550
# 15:53:33 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = 89.824, r_max = 90.0
# 15:53:34 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 4600
# 15:53:35 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = 89.708, r_max = 90.0
# 15:53:35 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 4650
# 15:53:36 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = 89.708, r_max = 90.0
# 15:53:36 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 4700
# 15:53:37 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = 89.76, r_max = 90.0
# 15:53:38 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 4750
# 15:53:39 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = 89.704, r_max = 90.0
# 15:53:39 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 4800
# 15:53:40 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = 89.724, r_max = 90.0
# 15:53:41 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 4850
# 15:53:41 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = 89.768, r_max = 90.0
# 15:53:42 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 4900
# 15:53:42 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = 89.72, r_max = 90.0
# 15:53:43 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 4950
# 15:53:44 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = 89.736, r_max = 90.0
# 15:53:45 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy being scored 250 times at iteration 5000
# 15:53:45 - lrl.solvers.base_solver - iterate_to_convergence - INFO - Current greedy policy achieved: r_mean = 89.748, r_max = 90.0
# 15:53:45 - lrl.solvers.base_solver - iterate_to_convergence - WARNING - Max iterations (5000) reached - solver did not converge

# %% [markdown]
# Like above, we can plot the number of policy changes per iteration.  But this plot looks very different from above and shows one view of why Q-Learning takes many more iterations (each iteration accomplishes a lot less learning than a planning algorithm)

# %%
rt_ql_iter_df = rt_ql.iteration_data.to_dataframe()
rt_ql_iter_df.plot(x='iteration', y='policy_changes', kind='scatter', )

# %% [markdown]
# We can access the intermediate scoring through the scoring_summary (GeneralIterationData) and scoring_walk_statistics (WalkStatistics) objects

# %%
rt_ql_intermediate_scoring_df = rt_ql.scoring_summary.to_dataframe()
rt_ql_intermediate_scoring_df
# Out:
#     iteration  reward_mean  reward_median  reward_std  reward_min  reward_max  \
# 0          50     -102.000         -102.0    0.000000      -102.0      -102.0
# 1         100     -103.000         -103.0    0.000000      -103.0      -103.0
# 2         150     -103.000         -103.0    0.000000      -103.0      -103.0
# 3         200     -102.000         -102.0    0.000000      -102.0      -102.0
# 4         250     -102.000         -102.0    0.000000      -102.0      -102.0
# 5         300     -100.000         -100.0    0.000000      -100.0      -100.0
# 6         350     -103.000         -103.0    0.000000      -103.0      -103.0
# 7         400     -100.000         -100.0    0.000000      -100.0      -100.0
# 8         450     -104.000         -104.0    0.000000      -104.0      -104.0
# 9         500     -103.000         -103.0    0.000000      -103.0      -103.0
# 10        550     -105.412         -105.0    0.676946      -109.0      -105.0
# 11        600     -103.000         -103.0    0.000000      -103.0      -103.0
# 12        650     -105.000         -105.0    0.000000      -105.0      -105.0
# 13        700     -103.000         -103.0    0.000000      -103.0      -103.0
# 14        750     -104.000         -104.0    0.000000      -104.0      -104.0
# 15        800     -100.000         -100.0    0.000000      -100.0      -100.0
# 16        850     -105.000         -105.0    0.000000      -105.0      -105.0
# 17        900     -104.648         -104.0    1.234543      -107.0      -104.0
# 18        950     -106.000         -106.0    0.000000      -106.0      -106.0
# 19       1000     -104.000         -104.0    0.000000      -104.0      -104.0
# 20       1050     -104.000         -104.0    0.000000      -104.0      -104.0
# 21       1100     -106.292         -106.0    0.773780      -113.0      -106.0
# 22       1150     -100.000         -100.0    0.000000      -100.0      -100.0
# 21       8.292           8.0   0.773780          8         15
# 22     101.000         101.0   0.000000        101        101
# 23       8.000           8.0   0.000000          8          8
# 24       7.536           7.0   0.885835          7          9
# 25      11.196          11.0   0.396969         11         12
# 26       7.000           7.0   0.000000          7          7
# 27       7.636           7.0   1.474959          6         10
# 28      34.072           7.0  42.566123          7        101
# 29       8.720           9.0   0.448999          8          9
# ..         ...           ...        ...        ...        ...
# 70      14.180          14.0   0.384187         14         15
# 71      80.708         101.0  36.627732         12        101
# 72      75.424         100.0  30.980062         22        101
# 73      14.392          18.0   6.309860          6         24
# 74      23.512          24.0   5.968070         12         45
# 75      40.380          31.0  26.404613         12        101
# 76      12.236          12.0   0.424622         12         13
# 77      12.244          12.0   0.429493         12         13
# 78      12.176          12.0   0.380820         12         13
# 79      12.220          12.0   0.414246         12         13
# 80      12.232          12.0   0.422109         12         13
# 81      12.236          12.0   0.424622         12         13
# 82      12.244          12.0   0.429493         12         13
# 83      12.204          12.0   0.402969         12         13
# 84      12.196          12.0   0.396969         12         13
# 85      12.276          12.0   0.447017         12         13
# 86      12.216          12.0   0.411514         12         13
# 87      12.296          12.0   0.456491         12         13
# 88      12.216          12.0   0.411514         12         13
# 89      12.236          12.0   0.424622         12         13
# 90      12.176          12.0   0.380820         12         13
# 91      12.292          12.0   0.454682         12         13
# 92      12.292          12.0   0.454682         12         13
# 93      12.240          12.0   0.427083         12         13
# 94      12.296          12.0   0.456491         12         13
# 95      12.276          12.0   0.447017         12         13
# 96      12.232          12.0   0.422109         12         13
# 97      12.280          12.0   0.448999         12         13
# 98      12.264          12.0   0.440799         12         13
# 99      12.252          12.0   0.434161         12         13
#
# [100 rows x 11 columns]

# %%
plt.plot(rt_ql_intermediate_scoring_df.loc[:, 'iteration'], rt_ql_intermediate_scoring_df.loc[:, 'reward_mean'], '-o')

# %% [markdown]
# In this case we see somewhere between the 3500th and 4000th iteration the solver finds a solution and starts building a policy around it.  This won't always be the case and learning may be more incremental

# %% [markdown]
# And if we wanted to access the actual episodes that went into one of these datapoints, they're available in a dictionary of WalkStatistics objects here (keyed by iteration number):

# %%
i = 3750
print(f'WalkStatistics for the scoring at iter == {i}:\n')
rt_ql.scoring_walk_statistics[i].to_dataframe().head()
# Out:
# WalkStatistics for the scoring at iter == 3750:
#    walk_index  reward  steps  terminal  reward_mean  reward_median  \
# 0           0    79.0     23      True    79.000000           79.0
# 1           1    78.0     24      True    78.500000           78.5
# 2           2    78.0     24      True    78.333333           78.0
# 3           3    78.0     24      True    78.250000           78.0
# 4           4  -110.0     12      True    40.600000           78.0
#
#    reward_std  reward_min  reward_max  steps_mean  steps_median  steps_std  \
# 0    0.000000        79.0        79.0   23.000000          23.0   0.000000
# 1    0.500000        78.0        79.0   23.500000          23.5   0.500000
# 2    0.471405        78.0        79.0   23.666667          24.0   0.471405
# 3    0.433013        78.0        79.0   23.750000          24.0   0.433013
# 4   75.300996      -110.0        79.0   21.400000          24.0   4.715930
#
#    steps_min  steps_max  terminal_fraction
# 0         23         23                1.0
# 1         23         24                1.0
# 2         23         24                1.0
# 3         23         24                1.0
# 4         12         24                1.0
